# %% [markdown]
# <a href="https://colab.research.google.com/github/Junhyuck123/MoonJick_study/blob/main/Mnist_classifier/run_main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !python3 './drive/MyDrive/Pytorch-mnist-36/train.py'
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# TRAIN: EPOCH 0005/0010 | BATCH 0629/0938 | LOSS: 0.1736 | ACC 0.9502
# TRAIN: EPOCH 0005/0010 | BATCH 0630/0938 | LOSS: 0.1738 | ACC 0.9502
# TRAIN: EPOCH 0005/0010 | BATCH 0631/0938 | LOSS: 0.1737 | ACC 0.9502
# TRAIN: EPOCH 0005/0010 | BATCH 0632/0938 | LOSS: 0.1735 | ACC 0.9503
# TRAIN: EPOCH 0005/0010 | BATCH 0633/0938 | LOSS: 0.1735 | ACC 0.9503
# TRAIN: EPOCH 0005/0010 | BATCH 0634/0938 | LOSS: 0.1736 | ACC 0.9503
# TRAIN: EPOCH 0005/0010 | BATCH 0635/0938 | LOSS: 0.1736 | ACC 0.9503
# TRAIN: EPOCH 0005/0010 | BATCH 0636/0938 | LOSS: 0.1734 | ACC 0.9503
# TRAIN: EPOCH 0005/0010 | BATCH 0637/0938 | LOSS: 0.1733 | ACC 0.9504
# TRAIN: EPOCH 0005/0010 | BATCH 0638/0938 | LOSS: 0.1731 | ACC 0.9504
# TRAIN: EPOCH 0005/0010 | BATCH 0639/0938 | LOSS: 0.1731 | ACC 0.9504
# TRAIN: EPOCH 0005/0010 | BATCH 0640/0938 | LOSS: 0.1731 | ACC 0.9504
# TRAIN: EPOCH 0005/0010 | BATCH 0641/0938 | LOSS: 0.1731 | ACC 0.9504
# ...

# %%
# !python3 './drive/MyDrive/Pytorch-mnist-36/eval.py'
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1331: UserWarning: dropout2d: Received a 2-D input to dropout2d, which is deprecated and will result in an error in a future release. To retain the behavior and silence this warning, please use dropout instead. Note that dropout2d exists to provide channel-wise dropout on inputs with 2 spatial dimensions, a channel dimension, and an optional batch dimension (i.e. 3D or 4D inputs).
#   warnings.warn(warn_msg)
# TEST: BATCH 0001/0157 | LOSS: 0.0328 | ACC 0.9844
# TEST: BATCH 0002/0157 | LOSS: 0.0214 | ACC 0.9922
# TEST: BATCH 0003/0157 | LOSS: 0.0162 | ACC 0.9948
# TEST: BATCH 0004/0157 | LOSS: 0.0193 | ACC 0.9922
# TEST: BATCH 0005/0157 | LOSS: 0.0196 | ACC 0.9938
# TEST: BATCH 0006/0157 | LOSS: 0.0246 | ACC 0.9922
# TEST: BATCH 0007/0157 | LOSS: 0.0312 | ACC 0.9911
# TEST: BATCH 0008/0157 | LOSS: 0.0379 | ACC 0.9902
# TEST: BATCH 0009/0157 | LOSS: 0.0367 | ACC 0.9896
# TEST: BATCH 0010/0157 | LOSS: 0.0390 | ACC 0.9875
# ...

# %%
# %load_ext tensorboard

# %%
tensorboard --logdir='./drive/My Drive/pytorch-mnist-36/log'
